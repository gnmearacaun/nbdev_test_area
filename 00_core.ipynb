# %% [raw]
# # default_exp core

# %% [markdown]
# ### Hello Nbdev From Briain
#
# > This is a first exploration of nbdev.

# %% [markdown]
# ####

# %%
#hide
from nbdev.showdoc import *

# %%
# export
def say_hello(to):
    "Say hello to somebody"
    return f'Hello {to}!'

# %%
say_hello("Briain")
# Out:
# 'Hello Briain!'

# %%
say_hello("Pete")
# Out:
# 'Hello Pete!'

# %%
from IPython.display import display,SVG

# %%
display(SVG('<svg height="100"><circle cx="50" cy="50" r="40"/></svg>'))

# %% [markdown]
# ### The next cell is running a test

# %%
assert say_hello("Jeremy")=="Hello Jeremy!"

# %% [markdown]
# ### the test did not fail
